# %%
import pandas as pd

# %%
import selenium

# %%
from selenium import webdriver

# %%
import time

# %%
driver=webdriver.Chrome('chromedriver.exe')
# Out:
# <ipython-input-126-ec23c7972a0a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.amazon.in/')

# %%
time.sleep(2)

# %%
search_item=driver.find_element_by_xpath("//input[@type='text']")
# Out:
# <ipython-input-129-0fb8c02b7860>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_item=driver.find_element_by_xpath("//input[@type='text']")

# %%
item=input('Enter item to be searched ')
# Out:
# Enter item to be searched Coffee

# %%
item
# Out:
# 'Coffee'

# %%
search_item.send_keys(item)

# %%
search_btn=driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
# Out:
# <ipython-input-133-50ddc53b2fc3>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")

# %%
search_btn.click()

# %%
brand=[]

# %%
name=[]

# %%
rating=[]

# %%
rating_no=[]

# %%
price=[]

# %%
exchange=[]

# %%
delivery=[]

# %%
availability=[]

# %%
url=[]

# %%
other_details=[]

# %%
page=[]

# %%
for i in driver.find_elements_by_xpath("//li[@class='a-normal']"):
    page.append(i.get_attribute("href"))
# Out:
# <ipython-input-146-19b5daa0db8a>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//li[@class='a-normal']"):

# %%
len(page)
# Out:
# 2

# %%
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
    url.append(i.get_attribute("href"))
# Out:
# <ipython-input-148-6fe9507a871f>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):

# %%
len(url)
# Out:
# 65

# %%
for i in url:
    driver.get(i)
    time.sleep(3)
    try:
        nm=driver.find_element_by_xpath("//div[@id='titleSection']")
        name.append(nm.text.replace('/n','new line'))
    except:
        name.append('-')
# Out:
# <ipython-input-150-612f248680e5>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nm=driver.find_element_by_xpath("//div[@id='titleSection']")

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        brn=driver.find_element_by_xpath("//div[@id='qpeTitleTag_feature_div']")
        brand.append(brn.text.replace('/n','new line'))
    except:
        brand.append('-')
# Out:
# <ipython-input-151-e709f6c1838e>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brn=driver.find_element_by_xpath("//div[@id='qpeTitleTag_feature_div']")

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        pri=driver.find_element_by_xpath("//span[@id='a-size-medium a-color-price priceBlockBuyingPriceString']")
        price.append(pri.text.replace('/n','new line'))
    except:
        price.append('-')
# Out:
# <ipython-input-152-4e55d034078f>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pri=driver.find_element_by_xpath("//span[@id='a-size-medium a-color-price priceBlockBuyingPriceString']")

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        rat=driver.find_element_by_xpath("//a[@id='acrCustomerReviewLink']")
        rating.append(rat.text.replace('/n','new line'))
    except:
        rating.append('-')
# Out:
# <ipython-input-153-539f47baafa4>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rat=driver.find_element_by_xpath("//a[@id='acrCustomerReviewLink']")

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        rtn=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")
        rating_no.append(rtn.text.replace('/n','new line'))
    except:
        rating_no.append('-')
# Out:
# <ipython-input-154-f5a295ab891d>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rtn=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        deli=driver.find_element_by_xpath("//div[@id='dynamicDeliveryMessage_feature_div']")
        delivery.append(deli.text.replace('/n','new line'))
    except:
        delivery.append('-')

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        avl=driver.find_element_by_xpath("//span[@class='availability_feature_div']")
        availability.append(avl.text.replace('/n','new line'))
    except:
        availability.append('-')
# Out:
# <ipython-input-160-59d2605f28e4>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   avl=driver.find_element_by_xpath("//div[@id='availability_feature_div']")

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        oth=driver.find_element_by_xpath("//div[@id='feature-bullets']")
        other_details.append(oth.text.replace('/n','new line'))
    except:
        other_details.append('-')
# Out:
# <ipython-input-161-9c54f8f5564a>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   oth=driver.find_element_by_xpath("//div[@id='feature-bullets']")

# %%
product=pd.DataFrame({})

# %%
len(url)
# Out:
# 65

# %%
len(name)
# Out:
# 65

# %%
len(brand)
# Out:
# 65

# %%
len(rating)
# Out:
# 65

# %%
len(price)
# Out:
# 65

# %%
len(availability)
# Out:
# 130

# %%
len(delivery)
# Out:
# 0

# %%
len(other_details)
# Out:
# 65

# %%
product['Title']=name[0:50]
product['Brand']=brand[0:50]
product['Rating']=rating[0:50]
product['Rating No']=rating_no[0:50]
product['Price']=price[0:50]
product['Availibility']=availability[0:50]
product['Delivery data']=delivery[0:50]
product['Other details']=other_details[0:50]
product['URL']=url[0:50]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-270a10c64f6e> in <module>
#       5 product['Price']=price[0:50]
#       6 product['Availibility']=availability[0:50]
# ----> 7 product['Delivery data']=delivery[0:50]
#       8 product['Other details']=other_details[0:50]
#       9 product['URL']=url[0:50]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...

# %%
product
# Out:
#                                                 Title Brand          Rating  \
# 0   Blue Tokai Coffee Roasters French Roast (Dark ...         1,008 ratings
# 1   Blue Tokai Coffee Roasters Vienna Roast Arabic...         2,350 ratings
# 2   TGL Co. The Good Life Company Euphoria Instant...         1,114 ratings
# 3   TGL Co. The Good Life Company Morning Motivati...           229 ratings
# 4   BRU Instant Coffee Powder 200g Pouch, Roasted ...         3,576 ratings
# 5               Nescafé Classic Coffee, 200g Dawn Jar         3,315 ratings
# 6               Tata Coffee Grand Filter Coffee, 500g           960 ratings
# 7   Rage Coffee 50 Gms Irish Hazelnut Flavoured Co...           796 ratings
# 8               Nescafé Classic Coffee, 100g Dawn Jar         6,767 ratings
# 9   Davidoff Cafe Instant Coffee Jar, Rich Aroma, ...         4,807 ratings
# 10  Nescafe Gold Blend Rich And Smooth Coffee Powd...        10,033 ratings
# ...

# %% [markdown]
# # Solution 3

# %%
import pandas as pd

# %%
import selenium

# %%
from selenium import webdriver

# %%
import time

# %%
driver=webdriver.Chrome('chromedriver.exe')
# Out:
# <ipython-input-236-ec23c7972a0a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

# %%
search_text=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
search_text.send_keys('fruits')
# Out:
# <ipython-input-238-2fada6ba6cb0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_text=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
search_btn=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
# Out:
# <ipython-input-240-e0b109f75fe0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")

# %%
search_btn.click()

# %%
fruits=[]

# %%
cars=[]

# %%
machi_learn=[]

# %%
fruit=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
# Out:
# <ipython-input-245-408c801e5942>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fruit=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")

# %%
len(fruit)
# Out:
# 48

# %%
for i in fruit:
    print(i.get_attribute('src'))
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR6SjYxZXy_JKZ6NhUw1ZlY2uLry91NcHxN6A&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQRfsCgcFwJCPGe-lJBHItC_dJmbArrdNAeCg&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSsZyKU4pEUcVP2x_GtXrgZ8kRbLhim4vwD5Q&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScPtz2ZoMJHYnZgrOoX4fWicItWpJT0savJQ&usqp=CAU
# None
# ...

# %%
import urllib

# %%
urllib.urlretrieve(src,"fruit.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-249-3850477aa66e> in <module>
# ----> 1 urllib.urlretrieve(src,"fruit.png")
#
# AttributeError: module 'urllib' has no attribute 'urlretrieve'

# %%
driver=webdriver.Chrome('chromedriver.exe')
# Out:
# <ipython-input-250-ec23c7972a0a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

# %%
search_text=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
# Out:
# <ipython-input-252-2fada6ba6cb0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_text=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
search_text.send_keys('cars')

# %%
search_btn=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
# Out:
# <ipython-input-254-e0b109f75fe0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")

# %%
search_btn.click()

# %%
car=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
# Out:
# <ipython-input-257-d896d8dcccae>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   car=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")

# %%
len(car)
# Out:
# 48

# %%
for i in car:
    print(i.get_attribute('src'))
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPTXYOJCG-NmDxyu_Rzo6oO5OMgCdRWgTkkA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSr_1d9kUp3SoTAkFJeBxNucG847bgMKAfzzA&usqp=CAU
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
url=[]

# %%
for i in driver.find_elements_by_xpath("//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']"):
    url.append(i.get_attribute("href"))
# Out:
# <ipython-input-266-936ba47f993c>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']"):

# %%
len(url)
# Out:
# 48

# %%
import os

# %%
import io

# %%
import requests
# Out:
# C:\Users\bshiv\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
from PIL import Image

# %%
os.chdir(r'C:/Users/bshiv/Desktop')

# %%
baseDir=os.getcwd()

# %% [markdown]
# for i, url in enumerate(url):
#     file_name = f"{i:150}.jpg"
#     try:
#         image_content = requests.get(url).content
#     except Exception as e:
#         print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

# %% [markdown]
# try:
#         image_file = io.BytesIO(image_content)
#         image = Image.open(image_file).convert('RGB')
#
#         file_path = os.path.join(baseDir, file_name)
#         with open(file_path, 'wb') as f:
#             image.save(f, "JPEG", quality=85)
#         print(f"SAVED - {url} - AT: {file_path}")
#     except Exception as e:
#         print(f"ERROR - COULD NOT SAVE {url} - {e}")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

# %%
search_text=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
search_text.send_keys('Machine Learning')

# %%
search_btn=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")

# %%
search_btn.click()
